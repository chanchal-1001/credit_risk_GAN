# %%
import requests
import json
import numpy as np
import pandas as pd

# %%
input_data = np.array(['A11',6,'A34','A43',1169,'A65','A75',4,'A93','A101',4,'A121',67,'A143','A152',2,'A173',1,'A192','A201'])

# %%
input_data = {'existingchecking'     :'A11', 
              'duration'             :6, 
              'credithistory'        :'A34', 
              'purpose'              :'A43', 
              'creditamount'         :1169, 
              'savings'              :'A65', 
              'employmentsince':, 
              'installmentrate':, 
              'statussex':, 
              'otherdebtors':, 
              'residencesince':, 
              'property':, 
              'age':, 
              'otherinstallmentplans':, 
              'housing':, 
              'existingcredits':, 
              'job':, 
              'peopleliable':, 
              'telephone':, 
              'foreignworker':]]
Y = data["classification"]

# %%
input_data = data.head(1).values.tolist()

# %%
data = json.dumps({"data": input_data})

# %%
response = requests.post('http://localhost:8049/predict', data=data)

# %%
print(response.text)
# Out:
# <!doctype html>
# <html lang=en>
#   <head>
#     <title>ValueError: Failed to find data adapter that can handle input: (&lt;class &#39;dict&#39;&gt; containing {&#34;&lt;class &#39;str&#39;&gt;&#34;} keys and {&#39;(&lt;class \&#39;list\&#39;&gt; containing values of types {\&#39;(&lt;class \\\&#39;list\\\&#39;&gt; containing values of types {&#34;&lt;class \\\&#39;int\\\&#39;&gt;&#34;, &#34;&lt;class \\\&#39;str\\\&#39;&gt;&#34;})\&#39;})&#39;} values), &lt;class &#39;NoneType&#39;&gt;
#  // Werkzeug Debugger</title>
#     <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css">
#     <link rel="shortcut icon"
#         href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>
#     <script>
#       var CONSOLE_MODE = false,
#           EVALEX = true,
#           EVALEX_TRUSTED = false,
#           SECRET = "fCfAP4rbWGp5wRY3XMJw";
#     </script>
#   </head>
# ...
